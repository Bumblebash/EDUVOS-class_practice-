# %%
correct_password = "admin123"
password = input("Enter password: ")
while password != correct_password:
    print("Incorrect password, Try again.")
    password = input("Enter password: ")
print("Access granted")
# Out:
# Enter password:  wdsvdsvds
# Incorrect password, Try again.
# Enter password:  admin123
# Access granted

# %%
for i in range(1,6):
    if i == 3:
        break
    print(i)
# Out:
# 1
# 2

# %%
s = input("Please type some charcaters and press enyter:")
for c in s:
    print(c)
print("Done")
# Out:
# Please type some charcaters and press enyter: advbs
# a
# d
# v
# b
# s
# Done

# %%
top = int(input("Please enter the numerator"))
bottom = int(input("Please enter the denominator: "))

if bottom != 0 and top % bottom == 0:
    print("The numerator is evenly divided by the denominator.")
else:
    print("The fraction is not a whole number.")
# Out:
# Please enter the numerator 0
# Please enter the denominator:  0
# The fraction is not a whole number.

# %%
age = float(input("Enter your age?"))
license = input("Do you have a  Fishing License?")
parent_license = input("Does ur parent have a Fishing License?")
if age > 15 and license.lower() == 'yes':
    print("You can fish")
elif age <=15 and parent_license.lower() == "yes":
    print("You can fish")
else:
    print("You cant Fish")
# Out:
# Enter your age? 16
# Do you have a  Fishing License? no
# Does ur parent have a Fishing License? yes
# You cant Fish
