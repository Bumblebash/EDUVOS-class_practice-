# %%
## total  = 0
count = 0
while True:
    num = input("Enter a Number?")
    if num.lower() == "-1":
        break     
    try:
        number = float(num)
    except:
        print("Enter a Valid Number")
    count+=1
    total+= number   
average = total / count
print(count, total, average)
# Out:
# Enter a Number? 1
# Enter a Number? 2
# Enter a Number? 3
# Enter a Number? 6
# Enter a Number? -1
# 4 444.4 111.1

# %%
age = 18
message = "You are " + str(age)+ "years old"
print(message)
# Out:
# You are 18years old

# %%
age = int(input("Please enter your age"))
age += 1
print ("This time next year your age will be:", age)
# Out:
# Please enter your age 23
# This time next year your age will be: 24

# %%
age = 19
print("Age:" + str(age))
# Out:
# Age:19

# %%
name = 'Faith'
age = 16
print(f'My name is {name} and I am {age} years old')
# Out:
# My name is Faith and I am 16 years old

# %%
name = 'Faith'
age = 16
print(f'My name is {name} and Iam {age} yeasr old')
# Out:
# My name is Faith and Iam 16 yeasr old

# %%
name = "Faith"
age = 16
print("My name is {} and I am {} years old".format(name, age))
# Out:
# My name is Faith and I am 16 years old

# %%
price = 12.3456
print(f"Price: {price:.2f}")
# Out:
# Price: 12.35

# %%
amount = 1000000
print(f"{amount:,}")
# Out:
# 1,000,000

# %% [markdown]
# ### Question
#  Activity
# - A school is selling tickets for an event.
#
# Each ticket costs R45.50
# A group of 7 learners wants to buy tickets
# They have a total of R350
# The program must:
#
# - a) Calculate the total cost of tickets
# - b) Calculate how many full tickets they can afford
# - c) Calculate how much money will be left over
# - d) Display a well-formatted message

# %%
def ticket_price():
    user_input1 = 0
    user_input2 = 0
    Balance = 0
    ticket_price = float(45.5)
    while True:
        inp1 = input("Enter Number of Students")
        inp2 = input("Enter Ammount")
        inp3 = input("Is that All?")
        try:
            user_input1 = float(inp1)
        except ValueError:
            print("Enter a Valid Numerical Value")
        try:
            user_input3 = str(inp3)
        except:
            print("Enter a Valid Respose(done)")
        try:
            user_input2 = float(inp2)
        except:
            print("Enter a Valid Numerical Value")
        if inp3.lower() == 'done':
            break
    total_cost = user_input1 * ticket_price
    possible_tickets = user_input2 / ticket_price
    Balance = float(user_input2 - total_cost)
    return total_cost, user_input1, possible_tickets, Balance
total_cost, user_input1, possible_tickets, Balance = ticket_price()
print("Number of Learners / Tickets Sold:", user_input1)
print("Total_cost/Money_spent:", f"R{total_cost}")
print("Possible Number of Tickets", int(possible_tickets))
print("Balance/Change:", f"R{Balance}")
# Out:
# Enter Number of Students 7
# Enter Ammount 350
# Is that All? done
# Number of Learners / Tickets Sold: 7.0
# Total_cost/Money_spent: R318.5
# Possible Number of Tickets 7
# Balance/Change: R31.5

# %%
total_tickets = 0
total_cost = 0 
Number_of_learners = 0
def ticket_price():
    ticket_price = float(45.5)
    while True:
        inp1 = input("Enter a Number of Students")
        if inp1.lower() == 'done':
            break 
        try:
            user_input = float(inp1)
        except ValueError:
            print("Enter a Valid Numerical Value")
    total_cost = float(user_input * ticket_price)

    return total_cost, user_input
total_cost, user_input = ticket_price()
print("Number_of_learners/Tickets sold:", user_input)
print("Total_cost/Money_spent:", f" R{total_cost}")
# Out:
# Enter a Number of Students 3
# Enter a Number of Students done
# Number_of_learners/Tickets sold: 3.0
# Total_cost/Money_spent:  R136.5

# %%
number = 5 * 2
print(number)
# Out:
# 10
