# %%
num1 = 2
num2 = 4
num5 = 5
summation = num1 + num2 + num5

average = summation / 3

print("summation", summation, "avearge", average)
# Out:
# summation 11 avearge 3.6666666666666665

# %%
user_input = []
count = 0
total = 0
while True:
    inp = input("Enter a number")
    if inp.lower() == "done":
        break
    try:
        number = float(inp)
        user_input.append(number)
    except ValueError:
        print("Enter a Valid Number")
    count +=1 
    total += number
average = total / count
print("user_input", user_input)
print("count", count)
print("sum", total )
print("average", average)
# Out:
# Enter a number 1
# Enter a number 2
# Enter a number 4
# Enter a number done
# user_input [1.0, 2.0, 4.0]
# count 3
# sum 7.0
# average 2.3333333333333335

# %% [markdown]
# - Write a program that prompts a user to input money/deposit money into the account , store it and then  withdraws,
# - The program should return the account balance and Message of Transaction successful

# %%
import sys
try:
    number = float(input("Enter a number?"))
except:
    print("enter a valid number")
    sys.exit()
if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number? sbdb
# enter a valid number
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
while True:
    
number  = int(input("Enter a number"))
if number % 2 == 0:
    print ("Even")
else:
    print("Odd")
# Out:
# Enter a number cjahbcahhcb
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 number  = int(input("Enter a number"))
#       2 if number % 2 == 0:
#       3     print ("Even")
#       4 else:
#
# ValueError: invalid literal for int() with base 10: 'cjahbcahhcb'

# %%
while True:
    try:
        number = float(input("Enter a number?"))
        break
    except ValueError:
        print("Enter a valid number . Try again.")
if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number? ahah
# Enter a valid number . Try again.
# Enter a number? aaha
# Enter a valid number . Try again.
# Enter a number? aavaf
# Enter a valid number . Try again.
# Enter a number? done
# Enter a valid number . Try again.
# Enter a number? 23
# Odd
