# %%
def ticket_price():
    number_of_stud = 0
    ammout = 0
    Balance = 0
    ticket_price = float(45.5)
    while True:
        try:
            number_of_stud = int(input("Enter the number of Students"))
            break
         except ValueError:
             
             print("Enter a Valid number, Please Try Again!") 
         try:
            ammount = float(input("Enter  ammount(In Rands)"))
            break
          except ValueError:
              print("Enter a Valid ammount!, Please try again")
          try:
            Endprompt = str(input("Is that All?"))
            break
           except:
               print("Enter a VALID RESPONSE!!")
           if Endprompt.lower() == 'done':
              break
    total_cost = user_input1 * ticket_price
    possible_tickets = user_input2 / ticket_price
    Balance = float(user_input2 - total_cost)
    return total_cost, user_input1, possible_tickets, Balance
total_cost, user_input1, possible_tickets, Balance = ticket_price()
print("Number of Learners / Tickets Sold:", user_input1)
print("Total_cost/Money_spent:", f"R{total_cost}")
print("Possible Number of Tickets", int(possible_tickets))
print("Balance/Change:", f"R{Balance}")
# Out:
#   File <string>:10
#     except ValueError:
#                       ^
# IndentationError: unindent does not match any outer indentation level

# %%
def ticket_price():
    user_input1 = 0
    user_input2 = 0
    Balance = 0
    ticket_price = float(45.5)
    while True:
        try:
            user_input1 = float(input("Enter Number of Students")) 
        except ValueError:
            print("Enter a Valid Numerical Value")
        try:
            user_input2 = float(input("Enter Ammount"))
        except:
            print("Enter a Valid Respose(done)")
        try:
            user_input3 = str(input("Is that all"))
        except:
            print("Enter a Valid Numerical Value")
        if user_input3.lower() == 'done':
            break
    total_cost = user_input1 * ticket_price
    possible_tickets = user_input2 / ticket_price
    Balance = float(user_input2 - total_cost)
    return total_cost, user_input1, possible_tickets, Balance
total_cost, user_input1, possible_tickets, Balance = ticket_price()
print("Number of Learners / Tickets Sold:", user_input1)
print("Total_cost/Money_spent:", f"R{total_cost}")
print("Possible Number of Tickets", int(possible_tickets))
print("Balance/Change:", f"R{Balance}")
# Out:
# Enter Number of Students 23
# Enter Ammount 1000
# Is that all done
# Number of Learners / Tickets Sold: 23.0
# Total_cost/Money_spent: R1046.5
# Possible Number of Tickets 21
# Balance/Change: R-46.5

# %%
def ticket_price():
    Number_of_stud = 0
    Ammount = 0
    Balance = 0
    ticket_price = float(45.5)
    while True:
        try:
            Number_of_stud = int(input("Enter Number of Students"))
            break
        except ValueError:
            print("Enter a Valid Numerical Input")
    while True:
        try:
            Ammount = float(input("Enter Ammount(In Rands)"))
            break
        except ValueError:
            print("Enter a Valid Nuerical value")
    total_cost = Number_of_stud * ticket_price
    possible_tickets = Ammount / ticket_price
    Balance = float(Ammount - total_cost)
    return total_cost, Number_of_stud, possible_tickets, Balance
total_cost, Number_of_stud, possible_tickets, Balance = ticket_price()
print("Number of Students / Tickets Sold:", Number_of_stud)
print("Total_cost/Money_spent:", f"R{total_cost}")
print("Possible  Number of tickets", int(possible_tickets))
print("Balance/Change", f"R{Balance}")
print("THANK U FOR CHOOSING US ☺✨")
# Out:
# Enter Number of Students 3
# Enter Ammount(In Rands) 305
# Number of Students / Tickets Sold: 3
# Total_cost/Money_spent: R136.5
# Possible  Number of tickets 6
# Balance/Change R168.5
# THANK U FOR CHOOSING US ☺✨

# %% [markdown]
# ### NOTE
#   -  #### BREAK
# - Break exits a loop once a condition is Met
# -    #### CONTINUE
# -    In case a condition is not met , Continue will force the user to go back into the loop
# -    Regardless of wether they are right or not
