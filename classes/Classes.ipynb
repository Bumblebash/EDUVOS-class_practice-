# %%
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        self.balance = self.balance + amount
        print("Deposit successful. New balance:", self.balance)


    def deposit(self, amount):
        self.balance = self.balance + amount 
        print("Deposit successful.New balance:", self.balance)

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance = self.balance - amount
            print("Withdrawal successful. Newbalance:", self.balance)
        else:
            print("Insufficient funds")

# %%
class Student:
    def __init__(self, name, age):
        self.name = name 
        self.age = age
    def display_info(self):
        print("Name:", self.name)
        print("Age:", self.age)

# %%
def __init_(self, name, age):
    self.name = name
    self.age = age

# %%
self.name 
self.age

# %%
class Student:
    school_name = "Greenwood High"

    def __init__(self, name, age, course):
        self.name = name
        self.age = age
        self.course = course
    def display_info(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Course:", self.course)
        print("School:", Student.school_name)

student1 = Student("Faith", 21, "Information Technology")
student2 = Student("John", 19, "Computer Science")

student1.display_info()
print()
student2.display_info()
# Out:
# Name: Faith
# Age: 21
# Course: Information Technology
# School: Greenwood High
#
# Name: John
# Age: 19
# Course: Computer Science
# School: Greenwood High

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance
        
    def deposit(self, amount):
        self.__balance += amount
        
    def get_balance(self):
        return self.__balance

# %%
class Person:
    def __init__(self, name):
        self.name = name
    def display_name(self):
        print("Name:", self.name)
class Student(Person):
    def __init__(self, name, course):
        super().__init__(name)
        self.course = course
    def display_course(self):
        print("Course:", self.course)
s = Student("Alice", "Computer Science")
s.display_name()
s.display_course()
# Out:
# Name: Alice
# Course: Computer Science

# %%
class Dog:
    def speak(self):
        print("Dog barks")
class Cat:
    def speak(self):
        print("Cat meows")
 
animal1 = Dog()
animal2 = Cat()

animal1.speak()
animal2.speak()
# Out:
# Dog barks
# Cat meows

# %%
class Person:
    def __init__(self, name):
        self.name = name
    def display_name(self):
        print("Name:", self.name)
p = Person("Faith")
p.display_name()
# Out:
# Name: Faith

# %%
class Ball(RawTurtle):
    def __init__ (self, cv, dx,dy):
        super (). __inti__ (cv)

        self.penup()
        self.shape(" soccerball.gif")
        self.dx = dx
        self.dy = dy

    def move(self):
        newx = self.xcor() + self.dx
        newy = self.ycor() + self.dy

# %%
class Rational:
    def __init__ (self, num=0, den=1):
        self.num = num
        self.den = den
def main():
    x = Rational(4,5)
    print(x)
if __name__ == " __main__ " :
    main()
def __str__ ( self ):
    return str(self.num)+ "/"+ str (self.den)

# %%
def main():
    x = Rational(4,5)
    y = Rational(9,12)

    lst = [x,y]
    print(lst)
main()
# Out:
# [<__main__.Rational object at 0x000001561B3FF0E0>, <__main__.Rational object at 0x000001561B40D090>]

# %%
def main():
    x = Rational(4,5)
    print(x)
    if __name__ == " __main__ " :
        main()

# %%
def __str__ (self):
    return str(self.num) +"/"+ str (self.den)

# %%
class Rational:
    def __init__ (self, num=0, den=1):
        self.num = num
        self.den = den
def main():
    x = Rational(4,5)
    print(x)
if __name__ == " __main__ " :
    main()
def __repr__ (self):
    return "Rational("+ str (self.num)+","+ str (self.den)+")"

# %%
def __str__ (self):
    return str (self.num)+ "/" + str(self.den)

# %%
nameList = ["Lee", "Lie", "Gorman", "Freeman", "Morgan"]
nameList. sort()
print(nameList)
# Out:
# ['Freeman', 'Gorman', 'Lee', 'Lie', 'Morgan']

# %%
def __lt__ (self, other):
    #commonDenominator = self.den * other.den
    selfNum = self .numertaor * other .den
    otherNum = other. numerator* self.den
    return selfNum < otherNum
