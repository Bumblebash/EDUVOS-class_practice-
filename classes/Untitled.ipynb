# %%
for i in range(1,6):
    if i == 4:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 5

# %%
x = 5
while x < 5:
    print(x)

# %%
a = [1,2,3]
b = a
print(b)
# Out:
# [1, 2, 3]

# %%
for i in range(1,6):
    if i == 4:
        break
    print(i, end="")
# Out:
# 123

# %%
a = [1,2,3]
b = a
print(id(a) == id(b))
# Out:
# True

# %%
def is_even(n):
    return n % 2 == 0
print(is_even(5))
# Out:
# False

# %%
def greet(name = "Guest"):
    return "Hello" + name 
print(greet())
# Out:
# HelloGuest

# %%
def power(base, exp=2):
    return base ** exp
print(power(3))
# Out:
# 9
