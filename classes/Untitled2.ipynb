# %%
class Student:
    school_name = "Glenville High School"
    def __init__(self, name, grade, age, course):
        self.name = name
        self.grade = grade 
        self.age = age
        self.course = course
    def display_info(self):
        print("Name:", self.name)
        print("grade:", self.grade)
        print("grade:", self.age)
        print("course:", self.course)
        print("School:", Student.school_name)
student1 = Student("bash", 7, 23, "Data Engineer")
student2 = Student("hosh", 8, 34, "DataBase Administrator")
student3 = Student("Henry", 5, 24, "MLE")

student1.display_info()
print()
student2.display_info()
print()
student3.display_info()
# Out:
# Name: bash
# grade: 7
# grade: 23
# course: Data Engineer
# School: Glenville High School
#
# Name: hosh
# grade: 8
# grade: 34
# course: DataBase Administrator
# School: Glenville High School
#
# Name: Henry
# grade: 5
# grade: 24
# course: MLE
# School: Glenville High School
