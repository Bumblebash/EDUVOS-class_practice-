# %%
import turtle 
t = turtle.Turtle()
screen = t.getscreen()
t.forward(25)
t.left(90)
t.forward(25)
t.left(90)
t.forward(25)
t.left(90)
t.left(25)
screen.exitonclick()

# %%
py -m pip install turtle
# Out:
#   Cell In[3], line 1
#     py -m pip install turtle
#           ^
# SyntaxError: invalid syntax

# %%
import turtle

# %%
from turtle import *
t = Turtle()
screen = t.getscreen()
t.forwad(25)
t.left(72.5)
t.forward(25)
t.left(
